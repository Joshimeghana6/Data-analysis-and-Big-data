# %%
#PHASE 1 — Basic Data Inspection (Pandas)

# %%
import pandas as pd

DATA_PATH = "C:/Users/Lenovo/PycharmProjects/data analysis and big data/flight_delays.csv"

# Load data
df = pd.read_csv(DATA_PATH)

# Basic inspection
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    FlightID    Airline  FlightNumber Origin Destination ScheduledDeparture  \
# 0         1     United          4558    ORD         MIA   2024-09-01 08:11
# 1         2      Delta          8021    LAX         MIA   2024-09-01 10:25
# 2         3  Southwest          7520    DFW         SFO   2024-09-01 16:53
# 3         4      Delta          2046    ORD         BOS   2024-09-01 14:44
# 4         5      Delta          6049    LAX         SEA   2024-09-01 01:51
#
#     ActualDeparture  ScheduledArrival     ActualArrival  DelayMinutes  \
# 0  2024-09-01 08:30  2024-09-01 12:11  2024-09-01 12:19             8
# 1  2024-09-01 10:41  2024-09-01 13:25  2024-09-01 13:27             2
# 2  2024-09-01 17:05  2024-09-01 17:53  2024-09-01 18:07            14
# 3  2024-09-01 15:04  2024-09-01 18:44  2024-09-01 18:34           -10
# 4  2024-09-01 02:08  2024-09-01 05:51  2024-09-01 06:15            24
#
#            DelayReason  Cancelled  Diverted AircraftType TailNumber  Distance
# 0              Weather       True     False   Boeing 737     N71066      1031
# 1  Air Traffic Control       True      True  Airbus A320     N22657      1006
# 2              Weather       True      True   Boeing 737     N95611      2980
# 3                  NaN      False     False   Boeing 777     N90029      1408
# 4  Air Traffic Control      False      True   Boeing 737     N27417      2298
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1747627 entries, 0 to 1747626
# Data columns (total 16 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   FlightID            int64
#  1   Airline             object
#  2   FlightNumber        int64
#  3   Origin              object
#  4   Destination         object
#  5   ScheduledDeparture  object
#  6   ActualDeparture     object
#  7   ScheduledArrival    object
#  8   ActualArrival       object
#  9   DelayMinutes        int64
#  10  DelayReason         object
#  11  Cancelled           bool
#  12  Diverted            bool
#  13  AircraftType        object
#  14  TailNumber          object
#  15  Distance            int64
# dtypes: bool(2), int64(4), object(10)
# memory usage: 190.0+ MB
# None
#            FlightID  FlightNumber  DelayMinutes      Distance
# count  1.747627e+06  1.747627e+06  1.747627e+06  1.747627e+06
# mean   8.738140e+05  5.001158e+03  9.999179e+00  1.549936e+03
# std    5.044966e+05  2.885822e+03  1.183112e+01  8.368681e+02
# min    1.000000e+00  1.000000e+00 -1.000000e+01  1.000000e+02
# 25%    4.369075e+05  2.503000e+03  0.000000e+00  8.250000e+02
# 50%    8.738140e+05  5.002000e+03  1.000000e+01  1.551000e+03
# 75%    1.310720e+06  7.499000e+03  2.000000e+01  2.274000e+03
# max    1.747627e+06  9.999000e+03  3.000000e+01  3.000000e+03

# %%
#PHASE 2 — Basic Cleaning

# %%
# Remove rows with missing Airline or DelayMinutes
df = df.dropna(subset=["Airline", "DelayMinutes"])

# Keep only delayed flights
df = df[df["DelayMinutes"] > 0]
df
# Out:
#          FlightID            Airline  FlightNumber Origin Destination  \
# 0               1             United          4558    ORD         MIA
# 1               2              Delta          8021    LAX         MIA
# 2               3          Southwest          7520    DFW         SFO
# 4               5              Delta          6049    LAX         SEA
# 6               7          Southwest          4188    ORD         JFK
# ...           ...                ...           ...    ...         ...
# 1747620   1747621          Southwest          3902    DFW         SEA
# 1747621   1747622  American Airlines          5071    DFW         SEA
# 1747623   1747624             United          2155    ATL         SEA
# 1747625   1747626              Delta          2940    JFK         SEA
# 1747626   1747627             United          1319    LAX         MIA
#
#         ScheduledDeparture   ActualDeparture  ScheduledArrival  \
# 0         2024-09-01 08:11  2024-09-01 08:30  2024-09-01 12:11
# 1         2024-09-01 10:25  2024-09-01 10:41  2024-09-01 13:25
# 2         2024-09-01 16:53  2024-09-01 17:05  2024-09-01 17:53
# 4         2024-09-01 01:51  2024-09-01 02:08  2024-09-01 05:51
# 6         2024-09-01 05:47  2024-09-01 06:02  2024-09-01 10:47
# ...                    ...               ...               ...
# 1747620   2024-09-01 19:21  2024-09-01 19:31  2024-09-02 01:21
# 1747621   2024-09-01 10:22  2024-09-01 10:38  2024-09-01 13:22
# 1747623   2024-09-01 20:43  2024-09-01 20:54  2024-09-01 21:43
# 1747625   2024-09-01 08:04  2024-09-01 08:07  2024-09-01 13:04
# 1747626   2024-09-01 12:46  2024-09-01 13:11  2024-09-01 15:46
#
#             ActualArrival  DelayMinutes          DelayReason  Cancelled  \
# 0        2024-09-01 12:19             8              Weather       True
# 1        2024-09-01 13:27             2  Air Traffic Control       True
# 2        2024-09-01 18:07            14              Weather       True
# 4        2024-09-01 06:15            24  Air Traffic Control      False
# 6        2024-09-01 10:54             7              Weather      False
# ...                   ...           ...                  ...        ...
# 1747620  2024-09-02 01:36            15              Weather       True
# 1747621  2024-09-01 13:27             5              Weather      False
# 1747623  2024-09-01 22:03            20              Weather       True
# 1747625  2024-09-01 13:20            16          Maintenance      False
# 1747626  2024-09-01 16:05            19          Maintenance       True
#
#          Diverted AircraftType TailNumber  Distance
# 0           False   Boeing 737     N71066      1031
# 1            True  Airbus A320     N22657      1006
# 2            True   Boeing 737     N95611      2980
# 4            True   Boeing 737     N27417      2298
# 6            True   Boeing 777     N25382      1674
# ...           ...          ...        ...       ...
# 1747620     False   Boeing 737     N30929      1253
# 1747621     False   Boeing 737     N22395      2887
# 1747623     False   Boeing 777     N68154      2185
# 1747625      True  Airbus A320     N94591      2793
# 1747626      True   Boeing 737     N76065      1501
#
# [1278754 rows x 16 columns]

# %%
#PHASE 3 — Exploratory Analysis

# %%
airline_summary = (
    df.groupby("Airline")["DelayMinutes"]
    .agg(["count","mean","max","std"])
    .sort_values("mean", ascending=False)
)

print(airline_summary.head())
# Out:
#                     count       mean  max       std
# Airline
# Southwest          320306  15.508426   30  8.660510
# American Airlines  319545  15.503347   30  8.669587
# United             319245  15.494739   30  8.652382
# Delta              319658  15.487230   30  8.639548

# %%
# PHASE 4 — Business Metric

# %%
import numpy as np

airline_summary["Severity_Index"] = (
    airline_summary["mean"] * np.log(airline_summary["count"])
)

print(airline_summary.head())
# Out:
#                     count       mean  max       std  Severity_Index
# Airline
# Southwest          320306  15.508426   30  8.660510      196.600818
# American Airlines  319545  15.503347   30  8.669587      196.499549
# United             319245  15.494739   30  8.652382      196.375894
# Delta              319658  15.487230   30  8.639548      196.300749

# %%
# PHASE 5 — Move to Production Abstraction

# %%
DELAY_COL = "DelayMinutes"
GROUP_COL = "Airline"
TOP_N = 5

def severity(avg, count):
    return avg * np.log(count)

# %%
# PHASE 6 — Pandas Production Engine

# %%
def pandas_engine(path):
    df = pd.read_csv(path)
    df = df[df[DELAY_COL] > 0]

    stats = (
        df.groupby(GROUP_COL)[DELAY_COL]
        .agg(["count","mean","max","std"])
        .rename(columns={
            "count":"Total_Delayed",
            "mean":"Avg_Delay",
            "max":"Max_Delay",
            "std":"Std_Delay"
        })
        .sort_values("Avg_Delay", ascending=False)
    )

    stats["Severity_Index"] = severity(stats["Avg_Delay"], stats["Total_Delayed"])
    return stats.head(TOP_N)

# %%
# PHASE 7 — Polars Production Engine

# %%
import polars as pl

def polars_engine(path):
    df = pl.read_csv(path)
    df = df.filter(pl.col(DELAY_COL) > 0)

    return (
        df.group_by(GROUP_COL)
        .agg([
            pl.len().alias("Total_Delayed"),
            pl.mean(DELAY_COL).alias("Avg_Delay"),
            pl.max(DELAY_COL).alias("Max_Delay"),
            pl.std(DELAY_COL).alias("Std_Delay")
        ])
        .with_columns(
            (pl.col("Avg_Delay") * pl.col("Total_Delayed").log()).alias("Severity_Index")
        )
        .sort("Avg_Delay", descending=True)
        .head(TOP_N)
    )

# %%
# PHASE 8 — Dask Production Engine

# %%
import dask.dataframe as dd

def dask_engine(path):
    df = dd.read_csv(path)
    df = df[df[DELAY_COL] > 0]

    stats = df.groupby(GROUP_COL).agg({
        DELAY_COL: ["count","mean","max","std"]
    })

    stats.columns = ["Total_Delayed","Avg_Delay","Max_Delay","Std_Delay"]
    stats["Severity_Index"] = stats["Avg_Delay"] * np.log(stats["Total_Delayed"])

    return stats.sort_values("Avg_Delay", ascending=False).head(TOP_N)

# %%
# PHASE 9 — PySpark Production Engine

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, mean, max, stddev, count, log

def spark_engine(path):
    spark = SparkSession.builder.appName("FlightAnalytics").getOrCreate()
    df = spark.read.csv(path, header=True, inferSchema=True)

    df = df.filter(col(DELAY_COL) > 0)

    return (
        df.groupBy(GROUP_COL)
        .agg(
            count(DELAY_COL).alias("Total_Delayed"),
            mean(DELAY_COL).alias("Avg_Delay"),
            max(DELAY_COL).alias("Max_Delay"),
            stddev(DELAY_COL).alias("Std_Delay")
        )
        .withColumn("Severity_Index", col("Avg_Delay") * log(col("Total_Delayed")))
        .orderBy(col("Avg_Delay").desc())
        .limit(TOP_N)
    )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from pyspark.sql import SparkSession
#       2 from pyspark.sql.functions import col, mean, max, stddev, count, log
#       4 def spark_engine(path):
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
# PHASE 10 — Orchestration Layer

# %%
def run_pipeline():
    print("\n--- PANDAS ---")
    print(pandas_engine(DATA_PATH))

    print("\n--- POLARS ---")
    print(polars_engine(DATA_PATH))

    print("\n--- DASK ---")
    print(dask_engine(DATA_PATH))

    print("\n--- PYSPARK ---")
    spark_engine(DATA_PATH).show()

# %%
# PHASE 11 - Execute

# %%
run_pipeline()
# Out:
# --- PANDAS ---
#                    Total_Delayed  Avg_Delay  Max_Delay  Std_Delay  \
# Airline
# Southwest                 320306  15.508426         30   8.660510
# American Airlines         319545  15.503347         30   8.669587
# United                    319245  15.494739         30   8.652382
# Delta                     319658  15.487230         30   8.639548
#
#                    Severity_Index
# Airline
# Southwest              196.600818
# American Airlines      196.499549
# United                 196.375894
# Delta                  196.300749
#
# --- POLARS ---
# shape: (4, 6)
# ┌───────────────────┬───────────────┬───────────┬───────────┬───────────┬────────────────┐
# │ Airline           ┆ Total_Delayed ┆ Avg_Delay ┆ Max_Delay ┆ Std_Delay ┆ Severity_Index │
# │ ---               ┆ ---           ┆ ---       ┆ ---       ┆ ---       ┆ ---            │
# │ str               ┆ u32           ┆ f64       ┆ i64       ┆ f64       ┆ f64            │
# ╞═══════════════════╪═══════════════╪═══════════╪═══════════╪═══════════╪════════════════╡
# │ Southwest         ┆ 320306        ┆ 15.508426 ┆ 30        ┆ 8.66051   ┆ 196.600818     │
# │ American Airlines ┆ 319545        ┆ 15.503347 ┆ 30        ┆ 8.669587  ┆ 196.499549     │
# │ United            ┆ 319245        ┆ 15.494739 ┆ 30        ┆ 8.652382  ┆ 196.375894     │
# │ Delta             ┆ 319658        ┆ 15.48723  ┆ 30        ┆ 8.639548  ┆ 196.300749     │
# └───────────────────┴───────────────┴───────────┴───────────┴───────────┴────────────────┘
#
# --- DASK ---
#                    Total_Delayed  Avg_Delay  Max_Delay  Std_Delay  \
# Airline
# Southwest                 320306  15.508426         30   8.660510
# American Airlines         319545  15.503347         30   8.669587
# United                    319245  15.494739         30   8.652382
# Delta                     319658  15.487230         30   8.639548
#
#                    Severity_Index
# Airline
# Southwest              196.600818
# American Airlines      196.499549
# United                 196.375894
# Delta                  196.300749
#
# --- PYSPARK ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 run_pipeline()
#
# Cell In[20], line 12, in run_pipeline()
#       9 print(dask_engine(DATA_PATH))
#      11 print("\n--- PYSPARK ---")
# ---> 12 spark_engine(DATA_PATH).show()
#
# NameError: name 'spark_engine' is not defined
